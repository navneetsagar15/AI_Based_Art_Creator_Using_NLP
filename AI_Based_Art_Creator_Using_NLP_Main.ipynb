# %% [markdown]
# AI BASED ART CREATOR USING NLP

# %%
# !pip install diffusers
# Out:
# ...
#   Using cached diffusers-0.26.3-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached importlib_metadata-7.0.1-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached huggingface_hub-0.20.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached regex-2023.12.25-cp312-cp312-win_amd64.whl.metadata (41 kB)
# ...
#   Using cached safetensors-0.4.2-cp312-none-win_amd64.whl.metadata (3.9 kB)
# ...
#   Using cached tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
# ...

# %%
# !pip install --upgrade  transformers accelerate scipy xformers gradio -q
# Out:
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#           main()
#         File "C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler
import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler
# ----> 2 import torch
#
# ModuleNotFoundError: No module named 'torch'

# %%
model_id = "stabilityai/stable-diffusion-2"
scheduler = EulerDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")
pipe = StableDiffusionPipeline.from_pretrained(model_id, scheduler=scheduler, revision="fp16", torch_dtype=torch.float16)
pipe = pipe.to("cuda")

# %%
def text2image(prompt):

  image = pipe(prompt, height=768, width=768, guidance_scale = 10).images[0] 
  image.save("sd_image.png")
  return image

# %%
prompt = "paradise cosmic beach"

# %%
text2image(prompt)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7F934AD70AF0>

# %%
# !pip install gradio -q

# %%
import gradio as gr 
gr.Interface(text2image, gr.Text(), gr.Image(), title = 'AI BASED ART CREATOR USING NLP').launch(share = True, debug = True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://7e1a6b6094efa8b3cd.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://7e1a6b6094efa8b3cd.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
#   0%|          | 0/50 [00:00<?, ?it/s]
